# %%
from asag2024_dataset.datasets.stita_loader import load_stita, rename_stita

# %%
stita = load_stita()
stita = rename_stita(stita)
stita.head()
# Out:
#    id data_source  question_id  question  \
# 0   0       stita            1       NaN
# 1   1       stita            1       NaN
# 2   2       stita            1       NaN
# 3   3       stita            1       NaN
# 4   4       stita            1       NaN
#
#                                     reference_answer  \
# 0  When we talk about characters we refer to all ...
# 1  When we talk about characters we refer to all ...
# 2  When we talk about characters we refer to all ...
# 3  When we talk about characters we refer to all ...
# 4  When we talk about characters we refer to all ...
#
#                                      provided_answer     grade  correct
# 0  When we talk about characters we refer to all ...  1.000000      NaN
# 1  Characters can be qualitative or quantitative....  0.590909      NaN
# 2  The characters in the statistical units may be...  0.704545      NaN
# 3  The types of characters are distinguished in q...  0.704545      NaN
# ...
